# %%
import pandas as pd

# %%
data = pd.read_csv("all_data_lat_lon.csv")
data
# Out:
#       ARRASTO    LOCAL   ESPECIE  N° DE INDIVIDUOS CT (cm) PESO (g)  PONTO  \
# 0         1.0  Náutico  Anc.brev               1.0     9.6     5.35      1
# 1         1.0  Náutico  Anc.brev               2.0       9     4.39      1
# 2         1.0  Náutico  Anc.brev               3.0     8.7     3.92      1
# 3         1.0  Náutico  Anc.brev               4.0       9     4.39      1
# 4         1.0  Náutico  Anc.brev               5.0     9.5     5.42      1
# ...       ...      ...       ...               ...     ...      ...    ...
# 10840      P4    TERRA  Bag. mar              10.0   17.02    33.59      4
# 10841      P4    TERRA  Bag. mar              11.0    19.0    49.12      4
# 10842      P4    TERRA  Bag. mar              12.0   17.01     32.4      4
# 10843      P4    TERRA  Bag. mar              13.0   13.03    13.83      4
# 10844      P4    TERRA  Bag. mar              14.0   12.04     7.06      4
#
#              DATA              TIPO  LATITUDE  LONGITUDE      NAME
# ...

# %%
data["NAME"] = data["ESPECIE"].apply(lambda x: x.replace(" ", "").upper())

# %%
data["NAME"].unique()
# Out:
# array(['ANC.BREV', 'HAE.CORV', 'CET.EDE', 'LAR.BRE', 'ACH.DEC', 'ACA.COE',
#        'SYM.PLA', 'SEL.BRO', 'CHL.CHR', 'CON.NOB', 'PEL.HAR', 'POL.VIR',
#        'STE.STE', 'DIA.RHO', 'SYM.TES', 'SPH.TES', 'GEN.PLA', 'BAG.MAR',
#        'NOT.GRA', 'EUC.ARG', 'HAE.PLU', 'ACA.CHI', 'ANI.MOR', 'SEL.VOM',
#        'ANI.VIRG', 'LYC.LIM', 'HAE.AUR', 'OPI.OGL', 'SPH.GRE', 'HAE.COR',
#        'EUC.GULA', 'BAI.RON', 'HAE.PAR', 'ORT.RUB', 'CUR.MAC', 'CIT.SPI',
#        'CHA.FAB', 'SPA.PLU', 'CAT.SPI', 'SPA.FRO', 'MEN.LIT', 'ANI.VIR',
#        'OPI.OLG', 'SEL.VÔM', 'TRA.FAL', 'CHI.SPI', 'ANC.BRE', 'SHP.TES',
#        'TRA.CAR', 'SPH.GUA', 'AMP.RUG', 'CHI.BLE', 'EUC.GUL', 'LUT.ANA',
#        'MOG.CUR', 'ETR.CRO', 'PRI.PUN', 'CYN.ACO', 'CEN.UND', 'ETH.FIM*',
#        'SCO.SAU*', 'NAR.BAN', 'GYM.MIC', 'TRI.LEP', 'SEL.SET', 'CEN.ENS',
#        'SCO.BRA', 'LYC.SP', 'LYC.GRO', 'ANC.SUR', 'CYN.MIC', 'LYC.LYM',
#        'GEN.GEN', 'CTA.SPI', 'GEN.MAC', 'SCI.HER', 'GEN.BAR', 'SCI.PAR',
# ...

# %%
data.to_csv("all_data_lat_lon.csv", index=False, encoding="UTF-8")
